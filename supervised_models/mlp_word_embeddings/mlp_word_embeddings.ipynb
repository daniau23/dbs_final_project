# %%
# !pip install gensim
# !pip install gensim==4.2.0 --force-reinstall
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.12/dist-packages (4.4.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from gensim) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.5.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open>=1.8.1->gensim) (2.0.1)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import string
import re
import warnings
import gensim.downloader as api
import gensim
warnings.filterwarnings("ignore")
import spacy

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## **MLP-word-embeddings Model**

# %%
data = pd.read_csv("/content/data/final_filtered_annotated_reviews.csv")

# %%
data.shape
# Out:
# (13594, 2)

# %%
data.columns
# Out:
# Index(['the_review', 'topics'], dtype='object')

# %%
data.head()
# Out:
#                                           the_review topics
# 0  I wish I would have gotten one earlier. I love...  mouse
# 1        It is so slow and lags find a better option  mouse
# 2  Beautifully produced and lovely to look at for...  mouse
# 3  I don't typically write reviews but I keep hav...  mouse
# 4  I bought this in late June, it looks cool with...  mouse

# %%
data.head()
# Out:
#                                           the_review topics
# 0  I wish I would have gotten one earlier. I love...  mouse
# 1        It is so slow and lags find a better option  mouse
# 2  Beautifully produced and lovely to look at for...  mouse
# 3  I don't typically write reviews but I keep hav...  mouse
# 4  I bought this in late June, it looks cool with...  mouse

# %% [markdown]
# ### **Data Preprocessing**

# %%
def preprocess(sent):
    '''Cleans text data up, leaving only 2 or
        more char long non-stopwords composed of A-Z & a-z only
        in lowercase'''
    # lowercase
    sentence = sent.lower()

    # Remove RT
    sentence = re.sub('RT @\w+: '," ",sentence)

    # Remove special characters
    sentence = re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ", sentence)

    # Removing digits
    sentence = sentence.translate(str.maketrans('', '', string.digits))

    # Single character removal
    sentence = re.sub(r"\s+[a-zA-Z]\s+", ' ', sentence) 
    # When we remove apostrophe from the word "Mark's", 
    # the apostrophe is replaced by an empty space. 
    # Hence, we are left with single character "s" that we are removing here.

    # Remove multiple spaces
    sentence = re.sub(r'\s+', ' ', sentence)  
    # Next, we remove all the single characters and replace it by a space 
    # which creates multiple spaces in our text. 
    # Finally, we remove the multiple spaces from our text as well.

    return sentence

# %%
text_cleaned = data.copy()
text_cleaned['cleaned_review'] = text_cleaned.the_review.apply(preprocess)

# %%
columns_needed = [
    "cleaned_review",
    "topics"
]

# %%
model_data = text_cleaned[columns_needed]

# %%
model_data.sample(2,random_state=42)
# Out:
#                                          cleaned_review     topics
# 1061  it is nice mouse and liked that it came with a...      mouse
# 3881                                           worth it  headphone

# %%
topics = model_data.topics.unique().tolist()
topics_mappings = {}
for index,value in enumerate(topics):
    topics_mappings[value]=index
topics_mappings
# Out:
# {'mouse': 0, 'headphone': 1, 'keyboard_speakers': 2}

# %%
model_data['topic_label'] = model_data.topics.map(topics_mappings)

# %%
model_data.head()
# Out:
#                                       cleaned_review topics  topic_label
# 0  i wish would have gotten one earlier love it a...  mouse            0
# 1          it is so slow and lags find better option  mouse            0
# 2  beautifully produced and lovely to look at for...  mouse            0
# 3  i don typically write reviews but keep having ...  mouse            0
# 4  i bought this in late june it looks cool with ...  mouse            0

# %%
list(api.info()['models'].keys())
# Out:
# ['fasttext-wiki-news-subwords-300',
#  'conceptnet-numberbatch-17-06-300',
#  'word2vec-ruscorpora-300',
#  'word2vec-google-news-300',
#  'glove-wiki-gigaword-50',
#  'glove-wiki-gigaword-100',
#  'glove-wiki-gigaword-200',
#  'glove-wiki-gigaword-300',
#  'glove-twitter-25',
#  'glove-twitter-50',
#  'glove-twitter-100',
#  'glove-twitter-200',
#  '__testing_word2vec-matrix-synopsis']

# %% [markdown]
# ### **Generating the Embeddings**

# %%
# https://github.com/piskvorky/gensim-data?tab=readme-ov-file
# https://radimrehurek.com/gensim/models/word2vec.html#embeddings-with-multiword-ngrams
glove_vectors_300 = api.load('glove-wiki-gigaword-300')
# Out:
# [==================================================] 100.0% 376.1/376.1MB downloaded

# %%
from spacy.lang.en.stop_words import STOP_WORDS
nlp = spacy.load("en_core_web_sm", exclude=["tagger", "ner",'attribute_ruler'])
nlp.pipe_names
# Out:
# ['tok2vec', 'parser', 'lemmatizer']

# %%
def spacy_tokeniser(sentence):
    sentence  = sentence.strip().lower()
    doc = nlp(sentence)
    my_tokens = [word.lemma_ for word in doc if word.text not in STOP_WORDS]
    return my_tokens

model_data['tokens'] = model_data['cleaned_review'].apply(spacy_tokeniser)

# %%
# Vectoriser of generating embeddings
def sent_vec(sent, vectorizer):
    vector_size = vectorizer.vector_size
    w2v_resolution = np.zeros(vector_size)
    # print(w2v_resolution)
    ctr = 1
    for w in sent:
        if w in vectorizer:
            ctr += 1
            w2v_resolution += vectorizer[w]
    w2v_resolution = w2v_resolution/ctr
    # print(w2v_resolution)
    return w2v_resolution

# %%
example = ['hello','mortal']
vectors = sent_vec(example,glove_vectors_300)

# %%
vectors.shape
# Out:
# (300,)

# %%
vectors.size
# Out:
# 300

# %%
vectors
# Out:
# array([-1.32264999e-01,  3.06633313e-02,  5.65678330e-02, -1.16517663e-01,
#        -5.19683321e-01,  2.13318006e-01, -3.05170000e-01, -7.94266661e-02,
#         1.18106168e-01, -3.69266669e-02,  2.29381672e-01, -8.71153322e-02,
#         1.68266694e-02, -2.73313344e-01,  6.77733372e-02, -2.48783335e-01,
#        -4.12300030e-02,  9.16800002e-02,  9.25767284e-02,  1.99719998e-01,
#         2.05836672e-01,  3.04553335e-01, -2.16043328e-01,  9.86980051e-02,
#         1.43205968e-01,  2.02186674e-01,  6.35446645e-02,  3.71666625e-03,
#         3.56219997e-01, -1.50553336e-02, -9.93000070e-02, -1.52218007e-01,
#         5.49630014e-02, -2.08299433e-01, -1.19527665e-01,  2.84936676e-02,
#        -1.71596669e-01, -4.90666628e-02,  2.90900022e-02,  3.59223336e-01,
#         2.23146657e-01,  6.18400003e-02, -3.43523333e-01,  2.33556673e-01,
#         7.58400063e-02,  1.45130003e-01,  3.78300001e-01, -2.73133337e-01,
#         1.37041998e-01, -6.49806609e-02, -1.86060006e-01,  1.18118663e-01,
#         2.80273339e-02,  3.71450007e-01, -2.11499999e-01, -2.78252332e-01,
#        -2.13466684e-02,  1.37630001e-01,  3.97779991e-01, -3.25799982e-02,
#         7.72613355e-02,  1.61273330e-01, -4.36266710e-02,  3.03609992e-01,
#         5.46983319e-02,  2.32234662e-01,  1.27930005e-01, -6.91199973e-02,
#         6.75333291e-03,  2.59599999e-01,  3.08573335e-01,  1.46543339e-01,
#         6.09066685e-02, -4.22406693e-02,  1.71162335e-01, -9.36866552e-03,
#         4.85866666e-02, -1.41451670e-01,  8.34529996e-02,  1.85486669e-01,
#        -2.45066682e-02,  1.89996660e-01,  3.74733309e-02,  1.87693328e-01,
#        -1.25620000e-01,  5.70053359e-02,  2.11666624e-02,  2.04916666e-01,
#         7.52547344e-02, -2.94291000e-01, -9.59016631e-02, -2.84533342e-01,
#        -1.37133300e-02, -3.26966663e-01, -3.59786650e-02, -5.10516651e-02,
#        -2.27750003e-01, -5.74000180e-03,  2.11030001e-01, -1.81166629e-02,
#        -2.80533334e-02, -2.36043334e-01, -6.92633390e-02,  2.52523333e-01,
#        -4.41000015e-02,  2.29900007e-02, -3.04690003e-02, -3.99656653e-01,
#         1.70933306e-02, -1.53733293e-02, -1.05150332e-01,  3.37796658e-01,
#        -1.22469991e-01, -1.13233328e-02,  1.21348662e-01,  2.83653345e-02,
#         2.91633358e-02, -6.63665930e-03,  9.23586624e-02, -1.85679326e-01,
#        -1.12568999e-01, -1.84626669e-01, -1.34426663e-01,  3.35973332e-01,
#        -6.73999985e-02, -6.77000483e-03, -3.01533341e-02,  6.72066646e-03,
#        -9.51966693e-02, -5.47799965e-02,  1.36540336e-01, -6.63399994e-02,
#         1.21203338e-01,  1.57333334e-01, -2.44140004e-01, -1.62096662e-01,
#         2.97200003e-02, -2.98936670e-01,  3.56566707e-02,  1.30306666e-01,
#         1.44044332e-01,  2.41180008e-01, -6.04716645e-02,  1.42495670e-01,
#        -8.92840028e-02, -4.54586695e-02,  2.24744336e-01,  5.93090008e-02,
#        -1.36373331e-01, -7.36399988e-02, -3.11036661e-01, -3.00493325e-01,
#        -2.46343344e-01,  5.81766665e-02,  1.69241197e-01, -5.19333283e-03,
#         5.99593346e-02,  8.61386682e-02, -1.13033329e-01,  3.01333343e-02,
#         1.36927001e-01,  9.32066689e-02, -1.34086664e-01,  6.67333603e-03,
#        -6.05200132e-02,  8.65469972e-02,  7.92386706e-02,  1.46066666e-01,
#         7.75800049e-02, -1.19109998e-01,  7.71966676e-02, -1.79600033e-03,
#        -6.08333349e-02,  1.57872667e-01, -2.89393855e-02,  7.48336669e-02,
#         1.42166669e-01,  1.56242001e-01,  1.90661334e-01,  5.53033402e-02,
#         9.75053310e-02, -2.22900013e-02,  7.69133307e-02,  8.27133308e-02,
#        -7.82153318e-02, -8.98823353e-02,  1.40799999e-01,  9.94693320e-02,
#         2.71063338e-01, -3.27736673e-02, -2.58503343e-01,  3.64999970e-03,
#         6.97666903e-03,  7.28359992e-02, -9.92566645e-02,  1.48270001e-01,
#        -2.12889997e-02, -4.05053337e-01, -8.37370033e-02, -2.36097335e-01,
#         5.60389996e-01,  2.66909997e-01,  5.09016653e-01,  5.87659975e-02,
#         1.41910002e-01, -1.93776667e-01, -1.10466679e-02, -4.83666658e-02,
#        -7.04839999e-02, -4.23100094e-02, -2.28126670e-01,  1.24771338e-01,
#        -6.38829991e-02, -1.63465670e-02,  6.20366683e-02,  3.79766673e-02,
#        -1.73166593e-02, -1.82613333e-01, -6.19085316e-02,  5.98066648e-02,
#        -2.87846665e-01,  2.61046668e-01,  1.29276004e-01,  1.79498668e-01,
#         4.96933311e-02,  7.25990012e-02,  1.22773334e-01,  9.68433358e-03,
#         3.96333337e-02,  8.18100025e-02,  1.23083323e-01, -3.46263329e-01,
#        -2.66373341e-01, -4.30513342e-01, -1.05453335e-01, -1.38274331e-01,
#         1.47810002e-01, -1.35247636e-01, -3.33553329e-02, -1.80973331e-01,
#        -1.21093333e-01, -8.92350028e-02, -1.45673330e-01,  6.91033403e-02,
#         1.35636660e-01,  5.20136667e-02, -2.10133334e-01, -4.34333086e-03,
#         3.20590009e-01,  1.35759999e-01,  8.67733260e-02,  7.47299989e-02,
#        -1.84263329e-01,  2.37120003e-01, -1.59273336e-01,  1.38879002e-01,
#         1.64269000e-01, -1.23916766e-01,  1.32713333e-01, -1.60189996e-01,
#        -1.98645904e-02, -5.60143332e-01,  1.36209997e-01, -1.24981004e-01,
#        -2.45703330e-01,  2.00382675e-01, -2.02685003e-01, -3.03813328e-01,
#        -2.21933424e-02,  2.66796668e-01,  1.07233326e-02,  1.89129988e-01,
#         6.50226672e-02, -1.18796666e-01, -1.43289000e-01,  1.94839999e-01,
#        -2.95953333e-01,  1.15518062e-01,  6.74666759e-05, -9.50333476e-03,
#        -2.80833344e-02,  1.92946663e-01, -4.13619995e-01, -9.16433334e-02,
#         9.90900099e-02,  2.80273338e-01, -9.18866644e-02, -1.07396667e-01,
#        -1.07114666e-01, -2.83783336e-01, -2.12680007e-01,  1.78133994e-01,
#         5.84766666e-02, -2.34498000e-01,  1.75656661e-01, -3.52829993e-01,
#         8.44029958e-02,  3.38283330e-01,  4.92333372e-03,  2.51153328e-01])

# %%
# https://www.includehelp.com/python/pandas-apply-function-with-two-arguments-to-columns.aspx
model_data["vectors"] = model_data.apply(lambda x: sent_vec(x['tokens'],glove_vectors_300),axis=1)

# %%
model_data.head()
# Out:
#                                       cleaned_review topics  topic_label  \
# 0  i wish would have gotten one earlier love it a...  mouse            0
# 1          it is so slow and lags find better option  mouse            0
# 2  beautifully produced and lovely to look at for...  mouse            0
# 3  i don typically write reviews but keep having ...  mouse            0
# 4  i bought this in late june it looks cool with ...  mouse            0
#
#                                               tokens  \
# 0  [wish, gotten, earlier, love, makes, working, ...
# 1                 [slow, lags, find, better, option]
# 2  [beautifully, produced, lovely, look, mouse, l...
# 3  [don, typically, write, reviews, having, issue...
# 4  [bought, late, june, looks, cool, lights, does...
#
#                                              vectors
# 0  [-0.14016066739956537, -0.0610214446981748, -0...
# 1  [-0.1662866696715355, 0.056922830641269684, 0....
# 2  [-0.17315801290576072, -0.06011226419222487, 0...
# 3  [-0.08608581582930955, 0.05318294558674097, 0....
# 4  [0.0540618986779009, -0.053416789431745805, -0...

# %%
model_data.loc[:2,['cleaned_review','vectors']]
# Out:
#                                       cleaned_review  \
# 0  i wish would have gotten one earlier love it a...
# 1          it is so slow and lags find better option
# 2  beautifully produced and lovely to look at for...
#
#                                              vectors
# 0  [-0.14016066739956537, -0.0610214446981748, -0...
# 1  [-0.1662866696715355, 0.056922830641269684, 0....
# 2  [-0.17315801290576072, -0.06011226419222487, 0...

# %%
model_data.vectors[0].size
# Out:
# 300

# %%
model_data.vectors[0].shape
# Out:
# (300,)

# %%
model_data.vectors[0]
# Out:
# array([-1.40160667e-01, -6.10214447e-02, -8.84855126e-02, -9.18836674e-02,
#        -7.57493560e-02, -1.18183335e-01, -4.15356679e-02, -7.02744455e-02,
#         1.45678779e-01, -1.25640666e+00,  4.87946669e-02, -9.80649425e-02,
#        -2.63786664e-02,  1.80620017e-02, -1.61834959e-01, -2.06819113e-01,
#        -1.62640689e-01, -1.46709047e-01,  5.01804443e-02,  9.58288932e-03,
#         1.47576999e-01,  2.70762492e-01,  3.70629428e-02,  4.31974505e-02,
#        -1.84584779e-01, -3.99994574e-02,  5.88773323e-02, -3.67805577e-02,
#         2.28363923e-01, -1.39704463e-02, -4.64357750e-02,  1.96774112e-01,
#        -1.73145558e-01, -8.19477646e-03, -8.10681115e-01,  5.34822238e-02,
#        -1.99908432e-01, -1.22876442e-01, -6.67182185e-02, -5.42835140e-02,
#         2.38051108e-02, -6.01313305e-02, -1.06867453e-01, -7.32689227e-03,
#         4.04209958e-02,  9.45728999e-02,  1.35278454e-01,  4.01843372e-02,
#        -8.52777788e-02, -1.11122330e-01,  1.90194227e-01, -5.89924663e-02,
#         3.98671118e-02,  7.45144453e-02, -1.62924998e-01,  1.25965223e-01,
#         2.09789665e-02,  7.54012184e-02,  1.63241115e-01,  2.39995544e-02,
#         7.19574458e-02, -2.44613319e-02,  7.60683330e-02,  2.05454663e-01,
#         4.32725557e-02, -8.55200026e-02,  1.24365588e-02,  7.70919981e-02,
#         8.45833578e-03,  1.68969668e-01, -5.78314484e-02, -1.35024221e-01,
#         4.47933210e-03,  1.96256111e-01,  2.34807338e-01,  2.19374448e-02,
#        -3.37844342e-03,  2.50445484e-02, -6.62977745e-03,  2.91213213e-02,
#        -1.82476559e-01,  4.24859971e-02,  1.47404116e-01, -1.31798892e-01,
#         2.53273431e-02,  1.38909974e-02, -2.54993296e-02,  1.25371554e-01,
#        -1.13298788e-01, -2.45874421e-02, -1.54240066e-01,  1.98489999e-01,
#        -2.05426885e-01, -1.84396113e-01,  6.59212230e-02, -1.49985333e-01,
#        -3.24748634e-01, -2.28597562e-01,  4.16677529e-02, -3.60384005e-01,
#        -8.16922213e-02, -1.82321875e-03, -1.09560888e-01, -1.37652255e-01,
#        -3.44754441e-02, -5.07383380e-02,  9.75151112e-02,  3.27334437e-02,
#        -2.93334772e-01, -5.72495875e-02, -1.17259625e-01, -2.59210000e-02,
#        -2.66064455e-02, -2.00635778e-01,  1.19913225e-01,  1.16400722e-01,
#         6.62448901e-02,  6.28276666e-02,  8.62478557e-02, -4.12842267e-02,
#        -4.26058898e-02, -1.29855105e-01,  9.57236642e-02,  5.52757776e-02,
#        -1.63700020e-02, -1.69806654e-02,  6.78785567e-02,  1.02062147e-01,
#         2.40553818e-02,  6.80061097e-02,  1.12020776e-01,  5.21822224e-02,
#        -2.95776655e-02,  9.41783570e-02, -7.26032412e-03, -5.33342208e-02,
#        -5.37194415e-02, -9.51131110e-02,  3.72616649e-02, -4.26854446e-02,
#         4.83473312e-02,  4.37724421e-02,  8.78942228e-02,  5.93569974e-02,
#        -2.96272222e-01, -3.84867779e-02, -1.30187332e-01, -2.70286683e-02,
#        -4.32292215e-02,  1.62482109e-02, -6.85404262e-02,  3.42187795e-02,
#         4.00293347e-02,  3.09542235e-02,  3.52937743e-02,  5.26059438e-02,
#        -9.50821107e-02,  3.01567813e-02,  6.16784460e-02, -3.14544447e-02,
#        -4.77333450e-03, -1.60834223e-01, -5.42092220e-02,  1.12568662e-02,
#         8.25263353e-02,  5.65719998e-02,  7.47421953e-03, -6.29191142e-02,
#        -4.55125556e-02,  2.31493318e-02, -1.84907001e-01, -7.92324437e-02,
#        -5.50597772e-01,  2.40375554e-01, -1.00227113e-01, -9.87123292e-02,
#        -2.40330004e-01, -1.25686668e-01, -7.87101774e-03,  3.77572675e-02,
#         2.06255800e-01,  6.83283287e-02,  1.43931223e-01, -5.55457799e-02,
#         1.40739552e-02,  3.02722088e-03,  4.79211095e-02,  1.03832410e-01,
#         1.50356782e-01, -8.91721543e-02, -9.93554418e-02, -6.14246697e-02,
#         8.61912233e-02, -4.64995547e-02, -1.84049999e-01, -1.18868088e-01,
#        -1.40524556e-01,  1.15984602e-01,  2.34987785e-02, -1.62009578e-01,
#         6.40004449e-01, -1.58775580e-02,  2.29789331e-01,  1.75926218e-01,
#         1.09681779e-01, -8.74200691e-02,  5.80202217e-02,  1.14600225e-01,
#        -1.05298670e-01, -1.43856109e-01, -2.34642673e-01,  3.15194452e-02,
#         7.43778915e-02,  4.96393364e-02,  4.59522258e-02, -8.50488875e-02,
#        -4.81291127e-02,  1.83962330e-01,  1.09256667e-01,  8.96244449e-02,
#         3.81198865e-02,  5.08611086e-02, -2.28101222e-01,  1.18214445e-01,
#        -4.04788868e-02, -8.41400151e-03,  1.57089223e-01, -5.95244451e-02,
#         2.82310766e-02,  3.25213340e-02, -1.37326693e-02, -4.29342244e-02,
#        -1.31050029e-02, -1.84139558e-01,  5.94100087e-03,  1.43928894e-02,
#        -4.82360000e-02,  2.16949887e-01, -7.66757731e-02, -4.46918868e-02,
#         1.38602220e-01,  5.17201658e-02,  1.39449888e-01, -4.13013314e-02,
#        -1.99192221e-01, -9.25713380e-02, -1.42142781e-01,  3.79419650e-02,
#        -1.27356447e-01, -3.46722280e-02,  3.32436752e-03, -9.58047809e-02,
#        -1.07997778e-01,  2.10194777e-01,  1.98149112e-01,  6.63059991e-02,
#         1.70226716e-01,  2.86777814e-02,  8.35166656e-02,  2.35503324e-02,
#        -1.30620330e-01, -9.24633352e-02, -1.59850000e-01, -1.33238445e-01,
#         1.61029188e-01,  2.03301476e-01, -1.01586666e-01, -1.15680887e-01,
#        -9.38444088e-04,  1.15206891e-01,  1.59971442e-01, -7.61804459e-02,
#         1.40644114e-01, -1.01791109e-01,  8.68008440e-02, -8.86433468e-03,
#        -1.43473334e+00,  2.67197755e-02,  1.69180999e-01, -6.67728604e-02,
#         3.16705577e-02,  1.36503362e-02,  1.28969000e-01,  1.04518006e-01,
#        -1.57735443e-01, -4.10034543e-02,  1.91290561e-01,  1.41945557e-01,
#        -1.25617768e-02, -7.80477885e-02, -4.12939613e-03, -1.45793446e-01,
#         9.51802205e-02, -1.51442211e-02,  9.20044457e-02, -1.10515561e-01,
#         2.18782235e-02, -1.72106677e-02, -3.69392186e-02,  1.08772445e-01])

# %% [markdown]
# ### **Model Training & Metrics**

# %%
from sklearn.neural_network import MLPClassifier
# from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report,confusion_matrix,\
ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline as Pipeline

# %%
# https://imbalanced-learn.org/stable/references/generated/imblearn.under_sampling.RandomUnderSampler.html
# https://imbalanced-learn.org/stable/references/generated/imblearn.pipeline.Pipeline.html

# %%
model_data.head()
# Out:
#                                       cleaned_review topics  topic_label  \
# 0  i wish would have gotten one earlier love it a...  mouse            0
# 1          it is so slow and lags find better option  mouse            0
# 2  beautifully produced and lovely to look at for...  mouse            0
# 3  i don typically write reviews but keep having ...  mouse            0
# 4  i bought this in late june it looks cool with ...  mouse            0
#
#                                               tokens  \
# 0  [wish, gotten, earlier, love, makes, working, ...
# 1                 [slow, lags, find, better, option]
# 2  [beautifully, produced, lovely, look, mouse, l...
# 3  [don, typically, write, reviews, having, issue...
# 4  [bought, late, june, looks, cool, lights, does...
#
#                                              vectors
# 0  [-0.14016066739956537, -0.0610214446981748, -0...
# 1  [-0.1662866696715355, 0.056922830641269684, 0....
# 2  [-0.17315801290576072, -0.06011226419222487, 0...
# 3  [-0.08608581582930955, 0.05318294558674097, 0....
# 4  [0.0540618986779009, -0.053416789431745805, -0...

# %%
X = model_data.loc[:,'vectors'].to_list()
y = model_data.loc[:,'topic_label'].to_list()

# %%
print(len(X))
print(len(y))
# Out:
# 13594
# 13594

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.20,
                                                    random_state=42,
                                                    stratify=y)

# %%
my_pipeline = Pipeline([
    ("under_sampler",RandomUnderSampler(random_state=42)),
    ("classifier",MLPClassifier(random_state=42))
    ]
)

# %%
my_pipeline
# Out:
# Pipeline(steps=[('under_sampler', RandomUnderSampler(random_state=42)),
#                 ('classifier', MLPClassifier(random_state=42))])

# %%
import time
start = time.time()
my_pipeline.fit(X_train,y_train)
end = time.time()
print(f" Training time: {end-start} in seconds")
# Out:
#  Training time: 22.95942449569702 in seconds

# %%
full_seconds = end - start
def convert_from_seconds(seconds):
  hours = int(seconds // 3600)
  minutes = int((seconds % 3600) // 60)
  seconds = int(seconds % 60)
  print(f"{hours} hours {minutes} minutes {seconds} seconds")
convert_from_seconds(full_seconds)
# Out:
# 0 hours 0 minutes 22 seconds

# %%
# Confirming the samples
sampler = my_pipeline.named_steps['under_sampler']
print(f"Sampling Strategy used: {sampler.sampling_strategy_}")
print(f"Number of samples in resampled data: {sampler.sample_indices_.shape}")
# Out:
# Sampling Strategy used: OrderedDict({np.int64(0): np.int64(2988), np.int64(1): np.int64(2988)})
# Number of samples in resampled data: (8964,)

# %%
resampled_indices = sampler.sample_indices_
print(resampled_indices.shape)
print(resampled_indices)
# Out:
# (8964,)
# [ 4959  1129  1177 ... 10865 10868 10870]

# %%
y_pred_train = my_pipeline.predict(X_train)

# %%
# Getting the resampled data for X_train
X_train_frame = pd.DataFrame(X_train)
X_train_resampled = X_train_frame.iloc[resampled_indices]

# %%
X_train_resampled.shape
# Out:
# (8964, 300)

# %%
# Getting the resampled data for y_train
y_train_frame = pd.DataFrame(y_train)
# y_train_frame.head()

y_train_resampled = y_train_frame.iloc[resampled_indices]
# y_train_resampled.to_numpy().ravel()
y_pred_train_resampled = y_pred_train[resampled_indices]

# %%
y_train_resampled.shape
# Out:
# (8964, 1)

# %%
# Classification report train data
sns.set_theme(style="white")
def class_report_train(model_name,model,y_train_resampled,y_pred_train_resampled):
    print(classification_report(y_train_resampled,y_pred_train_resampled))
    cm = confusion_matrix(y_train_resampled,y_pred_train_resampled)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=model.named_steps['classifier'].classes_)
    disp.plot()
    plt.savefig(f"/content/img/train_set_confusion_matrix_{model_name}")
    plt.show()

# %%
class_report_train('mlp-word-embeddings',my_pipeline,y_train_resampled,y_pred_train_resampled)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2988
#            1       1.00      1.00      1.00      2988
#            2       1.00      1.00      1.00      2988
#
#     accuracy                           1.00      8964
#    macro avg       1.00      1.00      1.00      8964
# weighted avg       1.00      1.00      1.00      8964

# %%
# https://www.scikit-yb.org/en/latest/api/classifier/rocauc.html?highlight=roc#yellowbrick.classifier.rocauc.ROCAUC

# %% [markdown]
# ### **Plotting the ROCAUC Curve**

# %%
from yellowbrick.classifier import ROCAUC
print(X_train_resampled.shape)
print(y_train_resampled.shape)

# Plotting the curve
visualiser_train = ROCAUC(my_pipeline, classes=[0,1,2])

visualiser_train.fit(X_train_resampled, y_train_resampled) # Fit the training data to the visualiser
visualiser_train.score(X_train_resampled, y_train_resampled) # Evaluate the model on the train data
visualiser_train.show() # Finalise and show the figure
# Out:
# (8964, 300)
# (8964, 1)
# <Axes: title={'center': 'ROC Curves for MLPClassifier'}, xlabel='False Positive Rate', ylabel='True Positive Rate'>

# %% [markdown]
# {'mouse': 0, 'headphone': 1, 'keyboard_speakers': 2}

# %% [markdown]
# ### **Model Test & Metrics**

# %%
y_pred = my_pipeline.predict(X_test)

# %%
# Classification report test data
sns.set_theme(style="white")
def class_report_test(model_name,model,y_test,y_pred):
    print(classification_report(y_test,y_pred))
    cm = confusion_matrix(y_test,y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=model.classes_)
    disp.plot()
    plt.savefig(f"/content/img/test_set_confusion_matrix_{model_name}")
    plt.show()

# %%
class_report_test("mlp-word-embeddings",my_pipeline,y_test,y_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.93      0.93      1093
#            1       0.90      0.87      0.89       879
#            2       0.83      0.87      0.85       747
#
#     accuracy                           0.89      2719
#    macro avg       0.89      0.89      0.89      2719
# weighted avg       0.89      0.89      0.89      2719

# %%
from yellowbrick.classifier import ROCAUC
visualiser_test = ROCAUC(my_pipeline, classes=[0,1,2])

visualiser_test.fit(X_train, y_train) # Fit the training data to the visualiser
visualiser_test.score(X_test, y_test) # Evaluate the model on the test data
visualiser_test.show() # Finalise and show the figure
# Out:
# <Axes: title={'center': 'ROC Curves for MLPClassifier'}, xlabel='False Positive Rate', ylabel='True Positive Rate'>

# %%
# Save the model with pickle
import pickle
with open('/content/models/mlp_word_embeddings.pkl', 'wb') as file:
    pickle.dump(my_pipeline, file)
